# %%
import pandas as pd
import numpy as np
import os 
import shutil
from sklearn.model_selection import train_test_split
import urllib

# %%
os.chdir('/nfsroot/data/home/B49gpu2/2373')

# %% [markdown]
# # Reading the data

# %%
data=pd.read_csv("train.csv")
test=pd.read_csv("test.csv")

# %%
os.getcwd()
# Out:
# '/nfsroot/data/home/B49gpu2/2373'

# %%
data.head() #observing the data
# Out:
#                    Brand Category Gender  Color  \
# 0  HRX by Hrithik Roshan  Tshirts    Men  Black
# 1  HRX by Hrithik Roshan  Tshirts    Men  White
# 2             FOREVER 21  Tshirts    Men  Olive
# 3             FOREVER 21  Tshirts    Men  Brown
# 4             Pepe Jeans  Tshirts    Men  Green
#
#                                    Link_to_the_image Sub_category
# 0  http://myntra.myntassets.com/assets/images/879...        Solid
# 1  http://myntra.myntassets.com/assets/images/191...        Solid
# 2  http://myntra.myntassets.com/assets/images/209...        Solid
# 3  http://myntra.myntassets.com/assets/images/179...        Solid
# 4  http://myntra.myntassets.com/assets/images/127...       Floral

# %%
data.describe()
# Out:
#              Brand Category Gender  Color  \
# count         6689     6689   6689   6682
# unique           5        1      4     38
# top     FOREVER 21  Tshirts    Men  White
# freq          1784     6689   4169   1046
#
#                                         Link_to_the_image Sub_category
# count                                                6646         6689
# unique                                               6634           22
# top     http://lacoste.in/media/catalog/product/p/f/pf...        Solid
# freq                                                    3         2585

# %%
print(data['Sub_category'].value_counts()) # we can observe high class imbalance
# Out:
# Solid                2585
# Typography           1774
# Striped               553
# Graphic               370
# Abstract              236
# Colourblocked         192
# People and Places     180
# Geometric             175
# Floral                146
# Conversational        135
# Tie and Dye            61
# Varsity                50
# Music                  48
# Biker                  47
# Camouflage             30
# Humour and Comic       29
# Superhero              25
# Self Design            15
# Tribal                 11
# Sports                 10
# Checked                10
# Polka Dots              7
# Name: Sub_category, dtype: int64

# %%
test['Sub_category'].unique() #looking at the unnique labels
# Out:
# array(['Solid', 'Striped', 'Typography', 'Colourblocked', 'Polka Dots',
#        'People and Places', 'Abstract', 'Conversational', 'Varsity',
#        'Humour and Comic', 'Floral', 'Graphic', 'Geometric', 'Superhero',
#        'Biker', 'Camouflage', 'Checked', 'Tie and Dye', 'Self Design',
#        'Music', 'Sports', 'Tribal'], dtype=object)

# %%
pd.isnull(data.Link_to_the_image).sum() #testing for the null values
# Out:
# 43

# %%
pd.isnull(test.Link_to_the_image).sum()
# Out:
# 19

# %%
test = test[test.Sub_category != 'Sports and Team Jersey'] #removing the extra class from test data

# %%
data.shape
# Out:
# (6689, 6)

# %%
test.shape
# Out:
# (2867, 6)

# %%
data= data.dropna(subset=['Link_to_the_image'])
test= test.dropna(subset=['Link_to_the_image'])

# %%
pd.isnull(data.Link_to_the_image).sum()
# Out:
# 0

# %%
pd.isnull(test.Link_to_the_image).sum()
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split #sepearting the labels and data

labels = data['Sub_category']
rest = data.drop("Sub_category",axis=1)

# %% [markdown]
# # splitting the data

# %%
X_train, X_val, y_train, y_val = train_test_split(rest, labels, test_size=0.15, random_state= 123,stratify=labels)

# %%
print(X_train.shape)
print(X_val.shape)
print(y_train.shape)
print(y_val.shape)
# Out:
# (5649, 5)
# (997, 5)
# (5649,)
# (997,)

# %%
train_data = X_train.join(y_train)
val_data = X_val.join(y_val)

# %%
print(train_data.shape)
print(val_data.shape)
# Out:
# (5649, 6)
# (997, 6)

# %%
train_data.head()
# Out:
#                       Brand Category Gender  Color  \
# 2944  HRX by Hrithik Roshan  Tshirts    Men  Black
# 6593             Pepe Jeans  Tshirts    Men  White
# 1689             FOREVER 21  Tshirts  Women  Black
# 5265             FOREVER 21  Tshirts  Women  Multi
# 1864           Jack & Jones  Tshirts    Men  White
#
#                                       Link_to_the_image Sub_category
# 2944  http://myntra.myntassets.com/assets/images/178...    Geometric
# 6593  http://myntra.myntassets.com/assets/images/179...   Typography
# 1689  http://myntra.myntassets.com/assets/images/220...        Solid
# 5265  http://myntra.myntassets.com/assets/images/128...      Striped
# 1864  http://myntra.myntassets.com/assets/images/115...     Abstract

# %%
train_data = train_data.reset_index(drop =True) #dropping the index column
val_data = val_data.reset_index(drop =True)

# %%
train_data.head()
# Out:
#                    Brand Category Gender  Color  \
# 0  HRX by Hrithik Roshan  Tshirts    Men  Black
# 1             Pepe Jeans  Tshirts    Men  White
# 2             FOREVER 21  Tshirts  Women  Black
# 3             FOREVER 21  Tshirts  Women  Multi
# 4           Jack & Jones  Tshirts    Men  White
#
#                                    Link_to_the_image Sub_category
# 0  http://myntra.myntassets.com/assets/images/178...    Geometric
# 1  http://myntra.myntassets.com/assets/images/179...   Typography
# 2  http://myntra.myntassets.com/assets/images/220...        Solid
# 3  http://myntra.myntassets.com/assets/images/128...      Striped
# 4  http://myntra.myntassets.com/assets/images/115...     Abstract

# %% [markdown]
# # downloading images from url's

# %%
##########################################################################################
from urllib import urlretrieve
i=0
for line in train_data.Link_to_the_image:
        urllib.urlretrieve(line, "img_train/" + train_data.iloc[i]['Sub_category']+'_'+ str(i) + ".jpg")
        print ("Image saved for {0}".format(line))
        i=i+1
        
    #except:
       # print("No url for " + train_data.iloc[i]['Brand'] + " " + "T-shirt")
        #i=i+1
        #continue
# Out:
# Image saved for http://myntra.myntassets.com/assets/images/1782031/2017/6/19/11497849560592-HRX-by-Hrithik-Roshan-Men-Black-Printed-Polo-Collar-T-shirt-7711497849560318-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1797778/2017/3/30/11490862273277-Pepe-Jeans-Men-White-Printed-Round-Neck-T-Shirt-241490862272989-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/2207055/2017/11/17/11510901178102-FOREVER-21-Women-Tops-7571510901177891-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1283009/2016/4/21/11461240044935-FOREVER-21-Blue--Off-White-Striped-Boxy-T-shirt-7711461240041822-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1150915/2016/1/14/11452754173227-Jack--Jones-White-Printed-T-shirt-661452754172683-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1167288/2016/4/5/11459835574382-HRX-by-Hrithik-Roshan-Burgandy-Active-Polo-T-shirt-2391459835573884-1.jpg
# ...

# %%
##########################################################################################
i=0
for line in val_data.Link_to_the_image:
        urllib.urlretrieve(line, "img_val/" + val_data.iloc[i]['Sub_category']+'_'+ str(i) + ".jpg")
        print ("Image saved for {0}".format(line))
        i=i+1
        
    #except:
        #print("No url for " + val_data.iloc[i]['Brand'] + " " + "T-shirt")
        #i=i+1
        #continue
# Out:
# Image saved for http://myntra.myntassets.com/assets/images/2119051/2017/10/6/11507281576504-FOREVER-21-Men-Tshirts-7401507281576334-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1793415/2017/6/5/11496660907713-FOREVER-21-Women-Tshirts-5201496660907390-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/2008783/2017/9/12/11505193238735-Jack--Jones-Men-Tshirts-9981505193238546-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1987210/2017/12/18/11513588389352-HRX-by-Hrithik-Roshan-Men-Charcoal-Solid-Round-Neck-T-shirt-5211513588389206-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1709427/2017/4/19/11492581511674-HRX-by-Hrithik-Roshan-Men-Navy-Blue-T-shirt-9141492581511469-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1879640/2017/5/8/11494222886898-Jack--Jones-Men-Tshirts-2571494222886684-1.jpg
# ...

# %%
##########################################################################################
i=0
for line in test.Link_to_the_image:
        urllib.urlretrieve(line, "img_test/" + test.iloc[i]['Sub_category']+'_'+ str(i) + ".jpg")
        print ("Image saved for {0}".format(line))
        i=i+1
        
    #except:
        #print("No url for " + test.iloc[i]['Brand'] + " " + "T-shirt")
        #i=i+1
        #continue
# Out:
# Image saved for http://myntra.myntassets.com/assets/images/1793459/2017/3/17/11489750536674-FOREVER-21-Men-Tshirts-5591489750536440-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/2021575/2017/8/1/11501571562590-Lacoste-L1212-polo-1521501571562482-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1739672/2017/2/15/11487138397377-Jack--Jones-Men-Yellow-Solid-Round-Neck-T-Shirt-7101487138397150-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1131319/2016/3/24/11458815078726-HRX-by-Hrithik-Roshan-Blue-Active-T-shirt-4721458815078220-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1450730/2016/8/19/11471604875639-FOREVER-21-Women-Mustard-Solid-Round-Neck-T-Shirt-7171471604875263-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1189387/2016/2/4/11454570785063-Pepe-Jeans-Brick-Red-Striped-Hooded-T-shirt-4691454570784456-1.jpg
# ...

# %%
categeory = data.Sub_category.unique() #extracting the unique lables from the data

# %% [markdown]
# # creating directories to store the images

# %%
##########################################################################################
os.chdir("/home/B49gpu2/2373")
if not os.path.exists("train_cat"):
    os.makedirs("train_cat")
if not os.path.exists("val_cat"):
    os.makedirs("val_cat")
if not os.path.exists("test_cat1"):
    os.makedirs("test_cat1")
for i in categeory:
    if not os.path.exists("train_cat/" + i):
        os.makedirs("train_cat/" +i)
    if not os.path.exists("val_cat/" + i):
        os.makedirs("val_cat/" +i)
    if not os.path.exists("test_cat1/" + i):
        os.makedirs("test_cat1/" +i)

# %%
##########################################################################################
#train_files = os.listdir("img_train/")
#val_files = os.listdir("img_val/")
test_files = os.listdir("img_test/")
import shutil

# %% [markdown]
# # function to store images based on the label

# %%
##########################################################################################
def copy_images(x,y):
    for i in x:
        if "Polka Dots" in i:
            shutil.copy("img_train/" + i,y + "/Polka Dots/")
        if "Tribal" in i:
            shutil.copy("img_train/" + i,y + "/Tribal/")
        if "Typography" in i:
            shutil.copy("img_train/" + i,y + "/Typography/")
        if "Striped" in i:
            shutil.copy("img_train/" + i,y + "/Striped/")
        if "Geometric" in i:
            shutil.copy("img_train/" + i,y + "/Geometric/")
        if "Colourblocked" in i:
            shutil.copy("img_train/" + i,y + "/Colourblocked/")
        if "Graphic" in i:
            shutil.copy("img_train/" + i,y + "/Graphic/")
        if "Camouflage" in i:
            shutil.copy("img_train/" + i,y + "/Camouflage/")
        if "Music" in i:
            shutil.copy("img_train/" + i,y + "/Music/")
        if "Solid" in i:
            shutil.copy("img_train/" + i,y + "/Solid/")
        if "Floral" in i:
            shutil.copy("img_train/" + i,y + "/Floral/")
        if "Checked" in i:
            shutil.copy("img_train/" + i,y + "/Checked/")
        if "Biker" in i:
            shutil.copy("img_train/" + i,y + "/Biker/")
        if "People and Places" in i:
            shutil.copy("img_train/" + i,y + "/People and Places/")
        if "Conversational" in i:
            shutil.copy("img_train/" + i,y + "/Conversational/")
        if "Self Design" in i:
            shutil.copy("img_train/" + i,y + "/Self Design/")
        if "Abstract" in i:
            shutil.copy("img_train/" + i,y + "/Abstract/")
        if "Superhero" in i:
            shutil.copy("img_train/" + i,y + "/Superhero/")
        if "Humour and Comic" in i:
            shutil.copy("img_train/" + i,y + "/Humour and Comic/")
        if "Tie and Dye" in i:
            shutil.copy("img_train/" + i,y + "/Tie and Dye/")
        if "Varsity" in i:
            shutil.copy("img_train/" + i,y + "/Varsity/")
        if "Sports" in i:
            shutil.copy("img_train/" + i,y + "/Sports/")

# %%
test_categeory = test.Sub_category.unique()

# %%
##########################################################################################
def copy_images(x,y):
    for i in x:
        if "Polka Dots" in i:
            shutil.copy("img_test/" + i,y + "/Polka Dots/")
        if "Tribal" in i:
            shutil.copy("img_test/" + i,y + "/Tribal/")
        if "Typography" in i:
            shutil.copy("img_test/" + i,y + "/Typography/")
        if "Striped" in i:
            shutil.copy("img_test/" + i,y + "/Striped/")
        if "Geometric" in i:
            shutil.copy("img_test/" + i,y + "/Geometric/")
        if "Colourblocked" in i:
            shutil.copy("img_test/" + i,y + "/Colourblocked/")
        if "Graphic" in i:
            shutil.copy("img_test/" + i,y + "/Graphic/")
        if "Camouflage" in i:
            shutil.copy("img_test/" + i,y + "/Camouflage/")
        if "Music" in i:
            shutil.copy("img_test/" + i,y + "/Music/")
        if "Solid" in i:
            shutil.copy("img_test/" + i,y + "/Solid/")
        if "Floral" in i:
            shutil.copy("img_test/" + i,y + "/Floral/")
        if "Checked" in i:
            shutil.copy("img_test/" + i,y + "/Checked/")
        if "Biker" in i:
            shutil.copy("img_test/" + i,y + "/Biker/")
        if "People and Places" in i:
            shutil.copy("img_test/" + i,y + "/People and Places/")
        if "Conversational" in i:
            shutil.copy("img_test/" + i,y + "/Conversational/")
        if "Self Design" in i:
            shutil.copy("img_test/" + i,y + "/Self Design/")
        if "Abstract" in i:
            shutil.copy("img_test/" + i,y + "/Abstract/")
        if "Superhero" in i:
            shutil.copy("img_test/" + i,y + "/Superhero/")
        if "Humour and Comic" in i:
            shutil.copy("img_test/" + i,y + "/Humour and Comic/")
        if "Tie and Dye" in i:
            shutil.copy("img_test/" + i,y + "/Tie and Dye/")
        if "Varsity" in i:
            shutil.copy("img_test/" + i,y + "/Varsity/")
        if "Sports" in i:
            shutil.copy("img_test/" + i,y + "/Sports/")

# %%
##########################################################################################
def copy_images(x,y):
    for i in x:
        if "Polka Dots" in i:
            shutil.copy("img_val/" + i,y + "/Polka Dots/")
        if "Tribal" in i:
            shutil.copy("img_val/" + i,y + "/Tribal/")
        if "Typography" in i:
            shutil.copy("img_val/" + i,y + "/Typography/")
        if "Striped" in i:
            shutil.copy("img_val/" + i,y + "/Striped/")
        if "Geometric" in i:
            shutil.copy("img_val/" + i,y + "/Geometric/")
        if "Colourblocked" in i:
            shutil.copy("img_val/" + i,y + "/Colourblocked/")
        if "Graphic" in i:
            shutil.copy("img_val/" + i,y + "/Graphic/")
        if "Camouflage" in i:
            shutil.copy("img_val/" + i,y + "/Camouflage/")
        if "Music" in i:
            shutil.copy("img_val/" + i,y + "/Music/")
        if "Solid" in i:
            shutil.copy("img_val/" + i,y + "/Solid/")
        if "Floral" in i:
            shutil.copy("img_val/" + i,y + "/Floral/")
        if "Checked" in i:
            shutil.copy("img_val/" + i,y + "/Checked/")
        if "Biker" in i:
            shutil.copy("img_val/" + i,y + "/Biker/")
        if "People and Places" in i:
            shutil.copy("img_val/" + i,y + "/People and Places/")
        if "Conversational" in i:
            shutil.copy("img_val/" + i,y + "/Conversational/")
        if "Self Design" in i:
            shutil.copy("img_val/" + i,y + "/Self Design/")
        if "Abstract" in i:
            shutil.copy("img_val/" + i,y + "/Abstract/")
        if "Superhero" in i:
            shutil.copy("img_val/" + i,y + "/Superhero/")
        if "Humour and Comic" in i:
            shutil.copy("img_val/" + i,y + "/Humour and Comic/")
        if "Tie and Dye" in i:
            shutil.copy("img_val/" + i,y + "/Tie and Dye/")
        if "Varsity" in i:
            shutil.copy("img_val/" + i,y + "/Varsity/")
        if "Sports" in i:
            shutil.copy("img_val/" + i,y + "/Sports/")

# %%
##########################################################################################
copy_images(train_files,"train_cat")

# %%
copy_images(test_files,"test_cat1")

# %%
##########################################################################################
copy_images(val_files,"val_cat")

# %% [markdown]
# # using image generator to augument the data

# %%
batch_size = 32

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

train_generator = datagen.flow_from_directory(
        'train_cat/',  # this is the target directory
        target_size=(150, 150),  # all images will be resized to 320*320
        batch_size=batch_size,
        classes=list(categeory))
# Out:
# Found 5649 images belonging to 22 classes.

# %%
val_generator = datagen.flow_from_directory(
        'val_cat/',  # this is the target directory
        target_size=(150, 150),  # all images will be resized to 320*320
        batch_size=batch_size,
        classes=list(categeory))
# Out:
# Found 997 images belonging to 22 classes.

# %%
test_generator = datagen.flow_from_directory(
        'test_cat1/',  # this is the target directory
        target_size=(150, 150),  # all images will be resized to 150x150
        batch_size=batch_size,
        classes=list(test_categeory))
# Out:
# Found 2848 images belonging to 22 classes.

# %%
print(train_generator.class_indices)
print(val_generator.class_indices)
print(test_generator.class_indices)
# Out:
# {'Superhero': 14, 'Camouflage': 7, 'Sports': 21, 'Music': 8, 'Polka Dots': 19, 'Checked': 18, 'Geometric': 4, 'People and Places': 10, 'Colourblocked': 5, 'Self Design': 12, 'Humour and Comic': 15, 'Varsity': 17, 'Floral': 1, 'Striped': 3, 'Tie and Dye': 16, 'Conversational': 11, 'Graphic': 6, 'Solid': 0, 'Tribal': 20, 'Typography': 2, 'Abstract': 13, 'Biker': 9}
# {'Superhero': 14, 'Camouflage': 7, 'Sports': 21, 'Music': 8, 'Polka Dots': 19, 'Checked': 18, 'Geometric': 4, 'People and Places': 10, 'Colourblocked': 5, 'Self Design': 12, 'Humour and Comic': 15, 'Varsity': 17, 'Floral': 1, 'Striped': 3, 'Tie and Dye': 16, 'Conversational': 11, 'Graphic': 6, 'Solid': 0, 'Tribal': 20, 'Typography': 2, 'Abstract': 13, 'Biker': 9}
# ...

# %%
from keras.models import Sequential
from keras.layers import Activation,Dense,Flatten
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import BatchNormalization
from keras.models import Model
from keras.layers.convolutional import *
from sklearn.metrics import confusion_matrix

# %%
nb_classes=22
model = Sequential()
model.add(Conv2D(32,kernel_size=(3,3),input_shape=(150,150,3),activation="relu"))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),activation="relu"))
#model.add(Conv2D(128,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(64,activation="relu"))
model.add(Dense(32,activation="relu"))
model.add(Dense(nb_classes,activation="softmax"))
# Out:
# WARNING:tensorflow:From /usr/lib64/python2.7/site-packages/keras/backend/tensorflow_backend.py:1205: calling reduce_prod (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
model.compile(loss="categorical_crossentropy",
             optimizer="adam",
             metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/lib64/python2.7/site-packages/keras/backend/tensorflow_backend.py:2755: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/lib64/python2.7/site-packages/keras/backend/tensorflow_backend.py:1290: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 146, 146, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 73, 73, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 71, 71, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 35, 35, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 78400)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                5017664
# ...

# %%
train_generator.n//train_generator.batch_size
# Out:
# 176

# %%
train_generator.batch_size
# Out:
# 32

# %%
model.fit_generator(train_generator,steps_per_epoch=(train_generator.n//train_generator.batch_size),
                    validation_data=val_generator,
                    validation_steps=(val_generator.n//val_generator.batch_size),
                    epochs=10)
# Out:
# Epoch 1/10

# %%
model.evaluate_generator(val_generator,steps=(val_generator.n//val_generator.batch_size))
# Out:
# [1.4946853518486023, 0.6622983870967742]

# %%
model.evaluate_generator(test_generator,steps=(test_generator.n//test_generator.batch_size))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-897b9f8f285b> in <module>()
# ----> 1 model.evaluate_generator(test_generator,steps=(test_generator.n//test_generator.batch_size))
#
# /usr/lib64/python2.7/site-packages/keras/legacy/interfaces.pyc in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /usr/lib64/python2.7/site-packages/keras/models.pyc in evaluate_generator(self, generator, steps, max_queue_size, workers, use_multiprocessing)
#    1159                                              max_queue_size=max_queue_size,
# ...

# %%
from keras import backend as K

# %%
from keras_applications.densenet import DenseNet201
from keras.layers import GlobalAveragePooling2D

# %%
from keras.applications.inception_v3 import InceptionV3,decode_predictions
from keras.layers import GlobalAveragePooling2D
trained_model = InceptionV3(include_top=False,weights='imagenet')

# %%
x = trained_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(300,activation='relu')(x)
x = BatchNormalization()(x)
pred_inception= Dense(22,activation='softmax')(x)
model = Model(inputs=trained_model.input,outputs=pred_inception)

# %%
for layer in trained_model.layers:
    layer.trainable=False
    
#compiling the model
adam = Adam(lr=0.001)
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer=adam)

# %%
model.fit_generator(train_generator,steps_per_epoch=(train_generator.n//train_generator.batch_size),
                    validation_data=val_generator,
                    validation_steps=(val_generator.n//val_generator.batch_size),
                    epochs=30,
                    verbose=1)
# Out:
# Epoch 1/30
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-89-696c8cbf9e8b> in <module>()
#       3                     validation_steps=(val_generator.n//val_generator.batch_size),
#       4                     epochs=30,
# ----> 5                     verbose=1)
#
# /usr/lib64/python2.7/site-packages/keras/legacy/interfaces.pyc in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# ...
